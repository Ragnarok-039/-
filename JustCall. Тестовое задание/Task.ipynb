# %%
import matplotlib.pyplot as plt
import numpy as np


zone = dict()
count = 0

# Произвел открытие файла.
with open("test.csv", encoding="utf-8") as my_file:
    for line in my_file:
        # Убрал со строк ненужные символы в начале и конце, разделил строку по ",".
        line = line.strip().split(",")
        # Этот блок добавил с целью убрать заголовок таблицы. Счетчик добавил больше для проверки себя.
        if line[2].isalpha():
            count += 1
            continue
        # Из строки выбираю округ, попутно удаляя ненужные символы.
        county = line[0].strip().split("_")
        county = " ".join(county)
        # Создаю словарь из пар: округ и список со всеми значениями длительности звонков.
        if county in zone:
            zone[county].append(float(line[1]))
        else:
            zone[county] = [float(line[1])]

for now in zone:
    # Вычисляю среднее время для каждого округа.
    my_mean = round(np.mean(zone[now]), 3)
    # Вычисляю медианное время для каждого округа.
    my_median = round(np.median(zone[now]), 3)
    # Печатаю вычисленные значения, дополнительно переводя в привычный формат времени "мин сек".
    print(f"Округ: {now}; среднее время: {my_mean}, что составляет: {my_mean // 1} мин {round(my_mean % 1 * 60, 2)} сек;"
          f" медианное время: {my_median}, что составляет: {my_median // 1} мин {round(my_median % 1 * 60, 2)} сек.")
    # Строю гистограмму по выбранному округу.
    # С целью минимизировать воздействие выбросов на график, ограничил его диапазоном от 0 до 3 мин.
    plt.hist(zone[now], bins=100, range={0, 3})
    plt.title(now)
    plt.show()
    # Дополнительно построил ящик с усами с целью показать не только медианные значения, но и первый и третий квартиль.
    plt.boxplot(zone[now], showfliers=False)
    plt.title(now)
    plt.show()
# Out:
# Округ: Дальневосточный федеральный округ МОБ; среднее время: 0.538, что составляет: 0.0 мин 32.28 сек; медианное время: 0.3, что составляет: 0.0 мин 18.0 сек.
# Округ: Северо-Западный федеральный округ  МОБ; среднее время: 0.557, что составляет: 0.0 мин 33.42 сек; медианное время: 0.233, что составляет: 0.0 мин 13.98 сек.
# Округ: Северо-Западный федеральный округ Санкт-Петербург  МОБ; среднее время: 0.356, что составляет: 0.0 мин 21.36 сек; медианное время: 0.167, что составляет: 0.0 мин 10.02 сек.
# Округ: Сибирский федеральный округ  МОБ; среднее время: 0.504, что составляет: 0.0 мин 30.24 сек; медианное время: 0.25, что составляет: 0.0 мин 15.0 сек.
# Округ: Центральный федеральный округ Москва  МОБ; среднее время: 0.533, что составляет: 0.0 мин 31.98 сек; медианное время: 0.267, что составляет: 0.0 мин 16.02 сек.
# Округ: Центральный федеральный округ  МОБ; среднее время: 0.529, что составляет: 0.0 мин 31.74 сек; медианное время: 0.233, что составляет: 0.0 мин 13.98 сек.
# Округ: Южный федеральный округ  МОБ; среднее время: 0.489, что составляет: 0.0 мин 29.34 сек; медианное время: 0.233, что составляет: 0.0 мин 13.98 сек.
# Округ: Приволжский федеральный округ МОБ; среднее время: 0.447, что составляет: 0.0 мин 26.82 сек; медианное время: 0.25, что составляет: 0.0 мин 15.0 сек.
# Округ: Уральский федеральный округ  МОБ; среднее время: 0.517, что составляет: 0.0 мин 31.02 сек; медианное время: 0.25, что составляет: 0.0 мин 15.0 сек.
# Округ: Москва; среднее время: 0.451, что составляет: 0.0 мин 27.06 сек; медианное время: 0.433, что составляет: 0.0 мин 25.98 сек.
# Округ: Северо-Кавказский федеральный округ МОБ; среднее время: 0.565, что составляет: 0.0 мин 33.9 сек; медианное время: 0.25, что составляет: 0.0 мин 15.0 сек.
# Округ: Санкт-Петербург; среднее время: 0.312, что составляет: 0.0 мин 18.72 сек; медианное время: 0.1, что составляет: 0.0 мин 6.0 сек.
# Округ: Омская область Омск; среднее время: 0.304, что составляет: 0.0 мин 18.24 сек; медианное время: 0.2, что составляет: 0.0 мин 12.0 сек.
# Округ: Ростовская область Ростов-на-Дону; среднее время: 2.889, что составляет: 2.0 мин 53.34 сек; медианное время: 0.7, что составляет: 0.0 мин 42.0 сек.
# Округ: Рязанская область Рязань; среднее время: 0.617, что составляет: 0.0 мин 37.02 сек; медианное время: 0.617, что составляет: 0.0 мин 37.02 сек.
# Округ: Красноярский край Красноярск; среднее время: 0.796, что составляет: 0.0 мин 47.76 сек; медианное время: 0.775, что составляет: 0.0 мин 46.5 сек.
# Округ: Кемеровская область; среднее время: 0.867, что составляет: 0.0 мин 52.02 сек; медианное время: 0.867, что составляет: 0.0 мин 52.02 сек.
# Округ: Смоленская область Смоленск; среднее время: 0.633, что составляет: 0.0 мин 37.98 сек; медианное время: 0.633, что составляет: 0.0 мин 37.98 сек.
# Округ: Хабаровский Край Хабаровск; среднее время: 0.717, что составляет: 0.0 мин 43.02 сек; медианное время: 0.483, что составляет: 0.0 мин 28.98 сек.
# Округ: Ставропольский край Ставрополь; среднее время: 0.942, что составляет: 0.0 мин 56.52 сек; медианное время: 0.942, что составляет: 0.0 мин 56.52 сек.
# Округ: Воронежская область Воронеж; среднее время: 0.183, что составляет: 0.0 мин 10.98 сек; медианное время: 0.183, что составляет: 0.0 мин 10.98 сек.
# Округ: Тульская область; среднее время: 2.512, что составляет: 2.0 мин 30.72 сек; медианное время: 0.667, что составляет: 0.0 мин 40.02 сек.
# Округ: Костромская область Кострома; среднее время: 2.633, что составляет: 2.0 мин 37.98 сек; медианное время: 2.633, что составляет: 2.0 мин 37.98 сек.
