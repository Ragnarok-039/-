# %%
import sqlite3
import os
import pandas as pd
import matplotlib.pyplot as plt

folder = os.getcwd()

sql_folder = fr'{folder}\SQL'

files_folder = fr'{folder}\files'
if not os.path.exists(files_folder):
    os.mkdir(files_folder)

db = fr'{folder}\db\testDB.sqlite3'
conn = sqlite3.connect(db)

# %%
sql_sales = fr'{sql_folder}\sales.sql'
sales = open(sql_sales).read()

df_sales = pd.read_sql_query(sales, conn)
df_sales[['BDate', 'PayDate']] = df_sales[['BDate', 'PayDate']].apply(pd.to_datetime)

# df_sales.to_csv(fr'{files_folder}\sales.csv', index=False, sep=';', encoding='utf-8')

df_sales.plot(kind = 'bar', x='PayDate', y='Cost')
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53982 entries, 0 to 53981
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   bcID     53982 non-null  object
#  1   bID      53982 non-null  object
#  2   piID     53982 non-null  int64
#  3   Cost     53982 non-null  float64
#  4   bID      53982 non-null  object
#  5   Num      53982 non-null  object
#  6   cID      53982 non-null  int64
#  7   scID     53982 non-null  object
#  8   BDate    53982 non-null  datetime64[ns]
#  9   PayDate  50508 non-null  datetime64[ns]
#  10  piID     53982 non-null  int64
#  11  product  53982 non-null  object
#  12  piName   53982 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(3), object(7)
# memory usage: 5.4+ MB
